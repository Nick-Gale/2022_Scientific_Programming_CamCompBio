# %% [markdown]
# # Data and Statistics in Julia

# %% [markdown]
# ## Data Loading

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# ## StatsBase and Statistics

# %% [markdown]
# ## Random Sampling

# %% [markdown]
# ## Statistics on Dataframes

# %% [markdown]
# ## Plotting

# %%
using DataFrames, Plots

# %%
10^1.3
# Out:
# 19.952623149688797

# %%
10^(1.6)
# Out:
# 39.810717055349734

# %%
sa(w) = 20*w^0.5;

# %%
alice_weight_data = 20 .+ 20 * rand(100);
bob_weight_data = 20 .+ 20 * rand(200);

# %%
asa = sa.(alice_weight_data) .+ 2 .* (2 .* rand(100) .- 1);
bsa = 70 .+ bob_weight_data .+ 0.5 .* bob_weight_data .* rand(length(bob_weight_data));
plot(alice_weight_data, asa; st=:scatter, c=:blue)
plot!(bob_weight_data, bsa; st=:scatter, c=:red)

# %%
plot(vcat(alice_weight_data, bob_weight_data), vcat(asa,bsa); st=:scatter)
